# %% [markdown]
# <a href="https://colab.research.google.com/github/opensim-org/opensim-viewer/blob/main/Convert_OpenCap_session_to_OpenSim_viewer_format_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Convert OpenCap session data to viewer format in Python

# %% [markdown]
# ## 1.1. Set up conda environment and install OpenSim

# %% [markdown]
# First, set up the environment by executing the following cell. In the following cell, you will use [`condacolab`](https://github.com/conda-incubator/condacolab) to install [`Miniconda`](https://docs.anaconda.com/miniconda/).

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %% [markdown]
# Don't worry if after executing the previous cell you get an error saying that your session has failed. The reason for this is that `condacolab` needs to restart the session for the changes to take effect. Because of this, you have to execute the previous cell first, before executing any other cell.

# %% [markdown]
# Now, let's install the OpenSim conda package.

# %%
# !conda install opensim-org::opensim
# Out:
# Channels:
#  - conda-forge
#  - opensim-org
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - opensim-org::opensim
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.7.14  |       hbd8a1cb_0         152 KB  conda-forge
#     certifi-2025.7.14          |     pyhd8ed1ab_0         156 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     libblas-3.9.0              |31_h59b9bed_openblas          16 KB  conda-forge
#     libcblas-3.9.0             |31_he106b2a_openblas          16 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_2          52 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_2          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hf1ad2bd_2         1.4 MB  conda-forge
#     liblapack-3.9.0            |31_h7ac8fdf_openblas          16 KB  conda-forge
#     libopenblas-0.3.29         |pthreads_h94d23a6_0         5.6 MB  conda-forge
#     numpy-2.0.2                |  py311h71ddf71_1         8.7 MB  conda-forge
#     openblas-0.3.29            |pthreads_h6ec200e_0         5.8 MB  conda-forge
#     opensim-4.5.2              |        py311np20        81.6 MB  opensim-org
#     openssl-3.5.1              |       h7b32b05_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       107.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   libblas            conda-forge/linux-64::libblas-3.9.0-31_h59b9bed_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-31_he106b2a_openblas
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_2
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_2
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hf1ad2bd_2
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-31_h7ac8fdf_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.29-pthreads_h94d23a6_0
#   numpy              conda-forge/linux-64::numpy-2.0.2-py311h71ddf71_1
#   openblas           conda-forge/linux-64::openblas-0.3.29-pthreads_h6ec200e_0
#   opensim            opensim-org/linux-64::opensim-4.5.2-py311np20
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.7.14-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.7.14-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 24.11.3-py311h38be061_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.5.1-h7b32b05_0
#
#
#
# Downloading and Extracting Packages:
# opensim-4.5.2        | 81.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
# numpy-2.0.2          | 8.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# openblas-0.3.29      | 5.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# openssl-3.5.1        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libgfortran-ng-14.2. | 53 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libgfortran-14.2.0   | 52 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 16 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 16 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 16 KB     | :   0% 0/1 [00:00<?, ?it/s]
# numpy-2.0.2          | 8.7 MB    | :   0% 0.0017909455807893103/1 [00:00<00:59, 59.17s/it]
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0.0027679004637044184/1 [00:00<00:42, 42.37s/it]
#
# openblas-0.3.29      | 5.8 MB    | :   0% 0.0027063067485716486/1 [00:00<00:45, 45.28s/it]
#
#
#
# openssl-3.5.1        | 3.0 MB    | :   1% 0.00523282961812225/1 [00:00<00:24, 24.28s/it]
# numpy-2.0.2          | 8.7 MB    | :  27% 0.27222372827997515/1 [00:00<00:00,  1.56it/s]
#
#
# libopenblas-0.3.29   | 5.6 MB    | :  55% 0.5452763913497705/1 [00:00<00:00,  2.98it/s]
#
# openblas-0.3.29      | 5.8 MB    | :  58% 0.5791496441943328/1 [00:00<00:00,  3.11it/s]
#
#
#
# openssl-3.5.1        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.34it/s]
#
#
#
# openssl-3.5.1        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.34it/s]
# numpy-2.0.2          | 8.7 MB    | :  84% 0.8435353685517651/1 [00:00<00:00,  3.40it/s]
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | :   1% 0.011206734985068174/1 [00:00<00:28, 28.98s/it]
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:00<00:00, 28.98s/it]
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
#
# openblas-0.3.29      | 5.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
#
# openblas-0.3.29      | 5.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.74it/s]
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | :  11% 0.10525639543100901/1 [00:00<00:03,  4.15s/it]
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | :   1% 0.01364371451460054/1 [00:00<00:31, 32.15s/it]
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | :  10% 0.10255704046821695/1 [00:00<00:03,  4.30s/it]
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | : 100% 1.0/1 [00:00<00:00,  4.15s/it]
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | : 100% 1.0/1 [00:00<00:00,  4.30s/it]
# numpy-2.0.2          | 8.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.40it/s]
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00, 32.15s/it]
#
#
#
#
#
#
#
#
# libgfortran-ng-14.2. | 53 KB     | :  30% 0.3046429036276752/1 [00:00<00:01,  1.68s/it]
#
#
#
#
#
#
#
#
# libgfortran-ng-14.2. | 53 KB     | : 100% 1.0/1 [00:00<00:00,  1.68s/it]
#
#
#
#
#
#
#
#
#
# libgfortran-14.2.0   | 52 KB     | :  30% 0.30491504289728844/1 [00:00<00:01,  1.70s/it]
#
#
#
#
#
#
#
#
#
# libgfortran-14.2.0   | 52 KB     | : 100% 1.0/1 [00:00<00:00,  1.70s/it]
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 16 KB     | :  97% 0.9718251379085355/1 [00:00<00:00,  1.82it/s]
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 16 KB     | : 100% 1.0/1 [00:00<00:00,  1.82it/s]
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 16 KB     | :  98% 0.9754703500833531/1 [00:00<00:00,  1.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 16 KB     | :  98% 0.9758189398451459/1 [00:00<00:00,  1.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 16 KB     | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 16 KB     | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.04it/s]
#
#
#
#
# libgfortran5-14.2.0  | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.04it/s]
#
#
#
# openssl-3.5.1        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.34it/s]
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | : 100% 1.0/1 [00:00<00:00,  1.28it/s]
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | : 100% 1.0/1 [00:00<00:00,  1.28it/s]
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
#
# openblas-0.3.29      | 5.8 MB    | : 100% 1.0/1 [00:01<00:00,  2.74it/s]
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
# libgfortran-ng-14.2. | 53 KB     | : 100% 1.0/1 [00:01<00:00,  1.92s/it]
#
#
#
#
#
#
#
#
# libgfortran-ng-14.2. | 53 KB     | : 100% 1.0/1 [00:01<00:00,  1.92s/it]
#
#
#
#
#
#
#
#
#
# libgfortran-14.2.0   | 52 KB     | : 100% 1.0/1 [00:01<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
#
# libgfortran-14.2.0   | 52 KB     | : 100% 1.0/1 [00:01<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 16 KB     | : 100% 1.0/1 [00:02<00:00,  1.82it/s]
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 16 KB     | : 100% 1.0/1 [00:02<00:00,  1.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 16 KB     | : 100% 1.0/1 [00:02<00:00,  1.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %% [markdown]
# ## 1.2. Install viewer backend

# %% [markdown]
# To visualize the motion capture data we collected from OpenCap, we will use the new OpenSim Viewer. Excecute the following lines to install the OpenSim Viewer and its dependencies.

# %%
# !pip install pygltflib

# Mount OpenSim Viewer code base.
# !git clone https://github.com/opensim-org/opensim-viewer-backend.git
# %cd opensim-viewer-backend
# !git checkout support_opencap_zipfiles
# Import the viewport module.
import sys
sys.path.append('opensim-viewer-backend')
import osimViewport
# Out:
# Collecting pygltflib
#   Downloading pygltflib-1.16.5-py3-none-any.whl.metadata (33 kB)
# Collecting dataclasses-json>=0.0.25 (from pygltflib)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated (from pygltflib)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.0.25->pygltflib)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json>=0.0.25->pygltflib)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting wrapt<2,>=1.10 (from deprecated->pygltflib)
#   Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json>=0.0.25->pygltflib) (24.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting typing-extensions>=3.7.4 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Downloading pygltflib-1.16.5-py3-none-any.whl (27 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Installing collected packages: wrapt, typing-extensions, mypy-extensions, marshmallow, typing-inspect, deprecated, dataclasses-json, pygltflib
# Successfully installed dataclasses-json-0.6.7 deprecated-1.2.18 marshmallow-3.26.1 mypy-extensions-1.1.0 pygltflib-1.16.5 typing-extensions-4.14.1 typing-inspect-0.9.0 wrapt-1.17.2
# Cloning into 'opensim-viewer-backend'...
# remote: Enumerating objects: 1690, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 1690 (delta 52), reused 54 (delta 52), pack-reused 1582 (from 1)
# Receiving objects: 100% (1690/1690), 28.09 MiB | 19.19 MiB/s, done.
# Resolving deltas: 100% (666/666), done.
# /content/opensim-viewer-backend
# Branch 'support_opencap_zipfiles' set up to track remote branch 'support_opencap_zipfiles' from 'origin'.
# Switched to a new branch 'support_opencap_zipfiles'

# %% [markdown]
# The visualization works by converting OpenSim data and model files into glTF ([Graphics Library Transmission Format](https://en.wikipedia.org/wiki/GlTF)) files. These files are used by the OpenSim Viewer and are universally viewable by other publicly available tools (e.g. Blender, 3D Viewer on Windows, and many other third party tools).

# %% [markdown]
# ## 1.3. Download OpenCap session zip file
#
# First, let's download the session zip file needed from OpenCap website, then upload the zip file to the /content folder of the notebook (the file name OpenCapData_c3820ac0.zip is used for illustration) please change to match your zip file in section 1.4 (3 places).

# %% [markdown]
# ## 1.4 Generate OpenSim viewer supported file.

# %%
# Generate a glTF file from the marker data.
import os
all_items = os.listdir('/content')
print(all_items)
import osimViewerOptions
ovp = osimViewport.osimViewport()
options =  osimViewerOptions.osimViewerOptions()
options.setShowMuscles(False)
ovp.addOpenCapZip('/content/OpenCapData_c3820ac0.zip', options)
ovp.saveGltf('/content/OpenCapData_c3820ac0.gltf')
# Out:
# ['.config', 'condacolab_install.log', '.ipynb_checkpoints', 'OpenCapData_c3820ac0.zip', 'opensim-viewer-backend', 'sample_data']
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/r_pelvis.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/l_pelvis.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/sacrum.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/r_femur.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/r_tibia.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/r_fibula.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/r_patella.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/r_talus.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/r_foot.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/r_bofoot.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/l_femur.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/l_tibia.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/l_fibula.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/l_patella.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/l_talus.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/l_foot.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/l_bofoot.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/hat_spine.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/hat_jaw.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/hat_skull.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/hat_ribs_scap.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/humerus_rv.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/ulna_rv.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/radius_rv.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/pisiform_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/lunate_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/scaphoid_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/triquetrum_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/hamate_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/capitate_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/trapezoid_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/trapezium_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal2_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/index_proximal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/index_medial_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/index_distal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal3_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/middle_proximal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/middle_medial_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/middle_distal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal4_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/ring_proximal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/ring_medial_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/ring_distal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal5_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/little_proximal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/little_medial_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/little_distal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal1_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/thumb_proximal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/thumb_distal_rvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/humerus_lv.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/ulna_lv.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/radius_lv.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/pisiform_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/lunate_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/scaphoid_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/triquetrum_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/hamate_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/capitate_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/trapezoid_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/trapezium_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal2_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/index_proximal_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/index_medial_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/index_distal_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal3_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/middle_proximal_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/middle_medial_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/middle_distal_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal4_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/ring_proximal_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/ring_medial_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/ring_distal_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal5_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/little_proximal_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/little_medial_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/little_distal_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/metacarpal1_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/thumb_proximal_lvs.vtp
# Loading file /content/OpenCapData_c3820ac0/OpenCapData_c3820ac0-85d1-48a4-a022-ffb921d30d27/OpenSimData/Model/Geometry/thumb_distal_lvs.vtp

# %% [markdown]
# Download the generated file locally, then drag and drop into the viewer below.

# %%
# @title Download the generated GLTF file to your computer { display-mode: "form" }
# @markdown After executing this cell, a button will appear to download the generated GLTF file to your computer.

import ipywidgets as widgets
from IPython.display import display
from google.colab import files
layout = widgets.Layout(width='250px')
button = widgets.Button(description="Download the GLTF file!", layout=layout)
output = widgets.Output()

def on_button_clicked(b):
  # Display the message within the output widget.
  with output:
    files.download('/content/OpenCapData_c3820ac0.gltf')

button.on_click(on_button_clicked)
display(button, output)
# Out:
# Button(description='Download the GLTF file!', layout=Layout(width='250px'), style=ButtonStyle())
# Output()

# %%
# @title Execute this cell to include the OpenSim Viewer { display-mode: "form" }
# @markdown Open the downloaded GLTF file from the Opensim Viewer to visualize.

from IPython.display import IFrame

IFrame('https://dev.d7iaa9a9lxtm6.amplifyapp.com/?css=gui', width=700, height=400)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="https://dev.d7iaa9a9lxtm6.amplifyapp.com/?css=gui"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 2. Conclusion

# %% [markdown]
# In this notebook we converted session data collected by OpenCap into a universally usable format.

# %% [markdown]
# ## 4. Useful Links

# %% [markdown]
# > **OpenSim Website:** https://opensim.stanford.edu/
# >
# > **OpenSim API Documentation:** https://simtk.org/api_docs/opensim/api_docs/
# >
# > **OpenSim Creator Website:** https://opensimcreator.com/
# >
# > **SimTK Website:** https://simtk.org/projects/opensim
# >
# > **Biomechanics of Movement's Course:** https://www.youtube.com/channel/UCDNGy0KKNLQ-ztcL5h2Z6zA
# >
# > **Webinar on Scaling and Inverse Kinematics in OpenSim:** https://www.youtube.com/watch?v=ZG7wzvQC6eU
